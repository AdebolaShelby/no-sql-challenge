# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from bson.decimal128 import Decimal128
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'autosaurus',
#  'classDB',
#  'config',
#  'epa',
#  'fruits_db',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'travel_db',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
collections = db.list_collection_names()
collections
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
document = db.establishments.find_one()
pprint(document)
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66ef81256e049f0c6e1f2a08'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#             'rel': 'self'}],
# ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours = {"BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang_flavours)
# Out:
# InsertOneResult(ObjectId('66ef81419bd7da6d3d7ac34b'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
establishments.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('66ef81419bd7da6d3d7ac34b'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
for doc in establishments.find({"BusinessType":"Restaurant/Cafe/Canteen"}, {"BusinessTypeID":1, "BusinessType":1}):
    pprint(doc)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a0f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66ef81256e049f0c6e1f2a12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
penang_flavors_id = establishments.update_one({"BusinessName":"Penang Flavours"}, {"$set":{"BusinessTypeID":"1"}})

# %%
# Confirm that the new restaurant was updated
pprint(establishments.find_one({"BusinessName":"Penang Flavours"}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66ef81419bd7da6d3d7ac34b'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})

pprint(f"There are {establishments.count_documents({'LocalAuthorityName': 'Dover'})} documents with LocalAuthorityName as Dover")
# Out:
# 'There are 994 documents with LocalAuthorityName as Dover'

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {"LocalAuthorityName":"Dover"}
establishments.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
query = {"LocalAuthorityName":"Dover"}
doc = establishments.find_one(query)
pprint(doc)
# Out:
# None

# %%
# Check that other documents remain with 'find_one'
query = ({"BusinessName": 1, "BusinessType": 1, "BusinessTypeID": 1, "PostCode": 1, "AddressLine1": 1,
          "PostCode": 1, "AddressLine1": 1, "AddressLine2": 1, "AddressLine3": 1, "AddressLine4": 1, "Phone": 1, "LocalAuthorityCode": 1, "LocalAuthorityName": 1,
          "LocalAuthorityWebSite": 1, "LocalAuthorityEmailAddress": 1, "scores": 1, "SchemeType": 1, "geocode": 1, "RightToReply": 1, "Distance": 1, 
          "NewRatingPending": 1})

#print one document
pprint(establishments.find_one({}, query))

# print all documents
#for doc in establishments.find({}, query):
    #pprint(doc)
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'Distance': 4591.821311183521,
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66ef81256e049f0c6e1f2cf0'),
#  'geocode': {'latitude': '51.086058', 'longitude': '1.196408'},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude

# Update all documents where longitude and latitude are stored as strings

documents = establishments.find({"geocode.longitude": {"$type": "string"}, "geocode.latitude": {"$type": "string"}})

# loop through the documents and update the data type

for doc in documents:
    longitude = Decimal128(doc["geocode"]["longitude"])
    latitude = Decimal128(doc["geocode"]["latitude"])
    establishments.update_one({"_id": doc["_id"]}, {"$set": {"geocode.longitude": longitude, "geocode.latitude": latitude}})

    # Update the document with the converted values

    establishments.update_one({"_id": doc["_id"]}, {"$set": {"geocode.longitude": longitude, "geocode.latitude": latitude}})


# Check that the data type has been updated
query = ["geocode.longitude", "geocode.latitude"]
result = establishments.find_one({}, query)
pprint(result)

for key, value in result.items():
    if type(value)==dict:  
        for inside_key, inside_value in value.items(): 
            print(f'The data type for {inside_key} is {type(inside_value)}')
    else:
        print(f"The data type for {key} is {type(value)}")
# Out:
# {'_id': ObjectId('66ef81256e049f0c6e1f2cf0'),
#  'geocode': {'latitude': Decimal128('51.086058'),
#              'longitude': Decimal128('1.196408')}}
# The data type for _id is <class 'bson.objectid.ObjectId'>
# The data type for longitude is <class 'bson.decimal128.Decimal128'>
# The data type for latitude is <class 'bson.decimal128.Decimal128'>

# %%
# Check that the data type was updated
query = ["geocode.longitude", "geocode.latitude"]
result = establishments.find_one({}, query)
pprint(result)

for inside_key, inside_value in result['geocode'].items(): 
    print(f'The data type for {inside_key} is {type(inside_value)}')
# Out:
# {'_id': ObjectId('66ef81256e049f0c6e1f2cf0'),
#  'geocode': {'latitude': Decimal128('51.086058'),
#              'longitude': Decimal128('1.196408')}}
# The data type for longitude is <class 'bson.decimal128.Decimal128'>
# The data type for latitude is <class 'bson.decimal128.Decimal128'>

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue

# find documents where RatingValue is stored as a string
documents = establishments.find({"RatingValue": {"$type": "string"}})

# loop through the documents and update the data type

for doc in documents:

    try:
        # convert the string to an integer
        rating = int(doc["RatingValue"])
        establishments.update_one({"_id": doc["_id"]}, {"$set": {"RatingValue": rating}})

    except ValueError:
        # if the string cannot be converted to an integer, set the value to None
        establishments.update_one({"_id": doc["_id"]}, {"$set": {"RatingValue": None}})

# Check that the data type has been updated
query = ["RatingValue"]
result = establishments.find_one({}, query)
pprint(result)

for key, value in result.items():
    print(f"The data type for {key} is {type(value)}")
# Out:
# {'RatingValue': 4, '_id': ObjectId('66ef81256e049f0c6e1f2cf0')}
# The data type for _id is <class 'bson.objectid.ObjectId'>
# The data type for RatingValue is <class 'int'>

# %%
# check that the coordinates and rating value are now numbers
query = ["geocode.longitude", "geocode.latitude", "RatingValue"]
result = establishments.find_one({}, query)

for key, value in result.items():
    if type(value)==dict:  
        for inside_key, inside_value in value.items(): 
            print(f'The data type for {inside_key} is {type(inside_value)}')
    else:
        print(f"The data type for {key} is {type(value)}")
# Out:
# The data type for _id is <class 'bson.objectid.ObjectId'>
# The data type for RatingValue is <class 'int'>
# The data type for longitude is <class 'bson.decimal128.Decimal128'>
# The data type for latitude is <class 'bson.decimal128.Decimal128'>

# %%
#establishments.find({})
#for doc in establishments.find():
    #pprint(doc)
